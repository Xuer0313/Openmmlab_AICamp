# %%
import sys
print(sys.executable)
# Out:
# /home/jin/anaconda3/envs/mmpose/bin/python

# %%
import os
os.chdir('mmdetection')
os.getcwd()
# Out:
# '/home/jin/xcy/task3/mmdetection'

# %%
# !python demo/image_demo.py ../inference.jpg configs/rtmdet/rtmdet_balloon.py --weights work_dirs/rtmdet_balloon/best_coco_bbox_mAP_epoch_190.pth --pred-score-thr 0.65
# Out:
# Loads checkpoint by local backend from path: work_dirs/rtmdet_balloon/best_coco_bbox_mAP_epoch_190.pth
# 06/11 16:52:16 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# 06/11 16:52:16 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /home/jin/anaconda3/envs/mmpose/lib/python3.7/site-packages/torch/functional.py:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to
# pass the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
from PIL import Image
Image.open('outputs/vis/inference.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x675>
